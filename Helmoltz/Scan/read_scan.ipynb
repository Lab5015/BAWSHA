# %%
from Utils import *

# %%
filename9 = r"C:\Users\ricca\Documents\Unimib-Code\BAWSHA\Helmoltz\Scan\geometry_scan_9.0.h5"
filename13 = r"C:\Users\ricca\Documents\Unimib-Code\BAWSHA\Helmoltz\Scan\geometry_scan_13.0.h5"
filename27 = r"C:\Users\ricca\Documents\Unimib-Code\BAWSHA\Helmoltz\Scan\geometry_scan_27.0.h5"

# %% [markdown]
# Usage: choose "quantity" argument:
# 1. "CR" for $\frac{\int_{0}^{R_0} dr |\psi(r)|^2 r}{\int_{0}^{\infty}|\psi(r)|^2 r}$
# 2. "Loss" for $\frac{\int_{R_0}^{\infty} dr |\psi(r)|^2 r}{\int_{0}^{\infty}|\psi(r)|^2 r}$
# 3. "HWHM" for half width at half maximum

# %%
filename = filename13

# %%
fig, axs = plot_geometry_heatmap(
    filename=filename,
    quantity="CR",        
    mode_index=0,         
    Rout=12.0,
    L0=9.0,
    cmap="plasma"
)

# %%
fig, axs = plot_geometry_heatmap(
    filename=filename13,
    quantity="Loss",        # oppure "Loss"
    mode_index=0,         # ground radial mode
    Rout=12.0,
    L0=9.0,
    cmap="plasma"
)

# %%
fig, axs = plot_geometry_heatmap(
    filename=filename,
    quantity="HWHM",        # oppure "Loss"
    mode_index=0,         # ground radial mode
    Rout=12.0,
    L0=9.0,
    cmap="plasma"
)
